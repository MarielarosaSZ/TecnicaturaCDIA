# %% [markdown]
# <a href="https://colab.research.google.com/github/MarielarosaSZ/TecnicaturaCDIA/blob/main/HeatMapSerie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌡️ Mapas de calor con Seaborn
# Seaborn ofrece la función seaborn.heatmap a nivel de ejes para generar mapas de calor. Esta herramienta permite visualizar matrices de datos en dos dimensiones, representando los valores mediante una paleta de colores.
#
# ## 🔧 Uso básico
# En su forma más simple, heatmap requiere como argumento un bloque de valores 2D. Si se utiliza un DataFrame, las etiquetas de filas y columnas se mostrarán automáticamente en el gráfico.

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# Generación de datos simulados
ventas = pd.DataFrame(
    np.random.randint(1, 100, 120).reshape(12, 10),
    columns = np.arange(2009, 2019),
    index = ["ene", "feb", "mar", "abr", "may", "jun", "jul", "ago", "sep", "oct", "nov", "dic"]
)

# Mapa de calor básico
ax = sns.heatmap(ventas)

# %%
# Personalización de colores : Puedes especificar una paleta de colores con el parámetro cmap:
ax = sns.heatmap(ventas, cmap="PiYG")

# %%
# Mostrar valores en las celdas: Para incluir los valores numéricos dentro de cada celda, usa el parámetro annot:

ax = sns.heatmap(ventas, cmap="Blues", annot=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar dataset (puede ser desde Drive o URL)
df = pd.read_csv('simpsons_episodes.csv')  # Asegurate de tener columnas: season, episode, imdb_rating

# %%
df
# Out:
#       id                                            title  \
# 0      0                Simpsons Roasting on an Open Fire
# 1      1                                  Bart the Genius
# 2      2                                  Homer's Odyssey
# 3      3                    There's No Disgrace Like Home
# 4      4                                 Bart the General
# ..   ...                                              ...
# 742  742                                     Fan-ily Feud
# 743  743                           Write Off This Episode
# 744  744                     The Very Hungry Caterpillars
# 745  745                      Clown V. Board of Education
# 746  746  Homer's Adventures Through the Windshield Glass
#
#                                            description original_air_date  \
# 0    Homer is forced to become a department store S...        1989-12-17
# 1    Bart ends up at a school for gifted children a...        1990-01-14
# ...

# %%
heatmap_data = df.pivot_table(values='imdb_rating', index='number_in_season', columns='season')
heatmap_data = heatmap_data.iloc[::-1]

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='RdYlGn', linewidths=0.5)
plt.title('Calificaciones IMDb por episodio - Los Simpsons')
plt.xlabel('Temporada')
plt.ylabel('Episodio')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Calificaciones IMDb por episodio - Los Simpsons')
plt.xlabel('Episodio')
plt.ylabel('Temporada')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='viridis', linewidths=0.5)
plt.title('Calificaciones IMDb por episodio - Los Simpsons')
plt.xlabel('Episodio')
plt.ylabel('Temporada')
plt.show()
